# %% [markdown]
# <a href="https://colab.research.google.com/github/avithetechy/AutoMetrics/blob/main/DA0101EN_CARDATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **READING CARDATASET**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
url="https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"

df=pd.read_csv(url,header=None)

# %%
df.head()
# Out:
#    symboling mormalized-losses         make fuel-type aspiration no-of-doors  \
# 0          3                 ?  alfa-romero       gas        std         two
# 1          3                 ?  alfa-romero       gas        std         two
# 2          1                 ?  alfa-romero       gas        std         two
# 3          2               164         audi       gas        std        four
# 4          2               164         audi       gas        std        four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# **ADDING HEADER TO DATAFRAME**

# %%
header=['symboling','mormalized-losses','make','fuel-type','aspiration','no-of-doors','body-style','drive-wheels','engine-location','wheel-base','length','width','height','curb-weight','engine-type','num-of-cylinders','engine-size','fuel-system','bore','stroke','compression-ratio','horsepower','peak-rpm','city-mpg','highway-mpg','price']
df.columns=header

# %% [markdown]
# **Saving as New CSV file**

# %%
df.to_csv('/content/drive/MyDrive/automobile.csv')

# %% [markdown]
# **To know the datatypes of each column**

# %%
df=pd.read_csv('/content/drive/MyDrive/automobile.csv')
df.dtypes
# Out:
# Unnamed: 0             int64
# symboling              int64
# mormalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# no-of-doors           object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# **statistical summary**

# %%
df.describe()
# Out:
#        Unnamed: 0   symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   102.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      0.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     51.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    102.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    153.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    204.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# ...

# %% [markdown]
# **describe(include='all')**

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0   symboling mormalized-losses    make fuel-type aspiration  \
# count   205.000000  205.000000               205     205       205        205
# unique         NaN         NaN                52      22         2          2
# top            NaN         NaN                 ?  toyota       gas        std
# freq           NaN         NaN                41      32       185        168
# mean    102.000000    0.834146               NaN     NaN       NaN        NaN
# std      59.322565    1.245307               NaN     NaN       NaN        NaN
# min       0.000000   -2.000000               NaN     NaN       NaN        NaN
# 25%      51.000000    0.000000               NaN     NaN       NaN        NaN
# 50%     102.000000    1.000000               NaN     NaN       NaN        NaN
# 75%     153.000000    2.000000               NaN     NaN       NaN        NaN
# max     204.000000    3.000000               NaN     NaN       NaN        NaN
#
# ...

# %% [markdown]
# **df.info() for summary-- top and bottom 30 rows**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         205 non-null    int64
#  1   symboling          205 non-null    int64
#  2   mormalized-losses  205 non-null    object
#  3   make               205 non-null    object
#  4   fuel-type          205 non-null    object
#  5   aspiration         205 non-null    object
#  6   no-of-doors        205 non-null    object
#  7   body-style         205 non-null    object
#  8   drive-wheels       205 non-null    object
#  9   engine-location    205 non-null    object
#  10  wheel-base         205 non-null    float64
#  11  length             205 non-null    float64
#  12  width              205 non-null    float64
#  13  height             205 non-null    float64
#  14  curb-weight        205 non-null    int64
#  15  engine-type        205 non-null    object
# ...

# %% [markdown]
# **Droping Na values**

# %%
df.dropna()
# Out:
#      symboling mormalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     no-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# ...

# %%
df.dropna(subset=['price'],axis=0,inplace=True)

# %%
df.head(25)
# Out:
#     Unnamed: 0  symboling mormalized-losses         make fuel-type aspiration  \
# 0            0          3               NaN  alfa-romero       gas        std
# 1            1          3               NaN  alfa-romero       gas        std
# 2            2          1               NaN  alfa-romero       gas        std
# 3            3          2               164         audi       gas        std
# 4            4          2               164         audi       gas        std
# 5            5          2               NaN         audi       gas        std
# 6            6          1               158         audi       gas        std
# 7            7          1               NaN         audi       gas        std
# 8            8          1               158         audi       gas      turbo
# 9            9          0               NaN         audi       gas      turbo
# 10          10          2               192          bmw       gas        std
# ...

# %% [markdown]
# **replacing ? missing values to NAN**

# %%
df.replace('?',np.nan)
# Out:
#      Unnamed: 0  symboling mormalized-losses         make fuel-type  \
# 0             0          3               NaN  alfa-romero       gas
# 1             1          3               NaN  alfa-romero       gas
# 2             2          1               NaN  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration no-of-doors   body-style drive-wheels engine-location  ...  \
# 0          std         two  convertible          rwd           front  ...
# ...

# %%
df.replace('?',np.nan,inplace=True)

# %%
df.head(10)
# Out:
#    Unnamed: 0  symboling mormalized-losses         make fuel-type aspiration  \
# 0           0          3               NaN  alfa-romero       gas        std
# 1           1          3               NaN  alfa-romero       gas        std
# 2           2          1               NaN  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
# 5           5          2               NaN         audi       gas        std
# 6           6          1               158         audi       gas        std
# 7           7          1               NaN         audi       gas        std
# 8           8          1               158         audi       gas      turbo
# 9           9          0               NaN         audi       gas      turbo
#
#   no-of-doors   body-style drive-wheels engine-location  ...  engine-size  \
# ...

# %%
df.dropna(subset=['mormalized-losses'],axis=0,inplace=True)
df.head(10)
# Out:
#     Unnamed: 0  symboling mormalized-losses       make fuel-type aspiration  \
# 3            3          2               164       audi       gas        std
# 4            4          2               164       audi       gas        std
# 6            6          1               158       audi       gas        std
# 8            8          1               158       audi       gas      turbo
# 10          10          2               192        bmw       gas        std
# 11          11          0               192        bmw       gas        std
# 12          12          0               188        bmw       gas        std
# 13          13          0               188        bmw       gas        std
# 18          18          2               121  chevrolet       gas        std
# 19          19          1                98  chevrolet       gas        std
#
#    no-of-doors body-style drive-wheels engine-location  ...  engine-size  \
# ...

# %% [markdown]
# **Replacing NAN with mean value**

# %%
df['mormalized-losses'].replace(np.nan,162,inplace=True)
df.head(20)
# Out:
#     Unnamed: 0  symboling mormalized-losses       make fuel-type aspiration  \
# 3            3          2               164       audi       gas        std
# 4            4          2               164       audi       gas        std
# 6            6          1               158       audi       gas        std
# 8            8          1               158       audi       gas      turbo
# 10          10          2               192        bmw       gas        std
# 11          11          0               192        bmw       gas        std
# 12          12          0               188        bmw       gas        std
# 13          13          0               188        bmw       gas        std
# 18          18          2               121  chevrolet       gas        std
# 19          19          1                98  chevrolet       gas        std
# 20          20          0                81  chevrolet       gas        std
# ...

# %% [markdown]
# **Column rename**

# %%
df.rename(columns={'mormalized-losses':'normalized-losses'},inplace=True)

# %% [markdown]
# **Formating the Data**

# %%
df['city-mpg']=235/df['city-mpg']
df.rename(columns={'city-mpg':'city-L/100km'},inplace=True)

# %%
df.head()
# Out:
#     Unnamed: 0  symboling normalized-losses  make fuel-type aspiration  \
# 3            3          2               164  audi       gas        std
# 4            4          2               164  audi       gas        std
# 6            6          1               158  audi       gas        std
# 8            8          1               158  audi       gas      turbo
# 10          10          2               192   bmw       gas        std
#
#    no-of-doors body-style drive-wheels engine-location  ...  fuel-system  \
# 3         four      sedan          fwd           front  ...         mpfi
# 4         four      sedan          4wd           front  ...         mpfi
# 6         four      sedan          fwd           front  ...         mpfi
# 8         four      sedan          fwd           front  ...         mpfi
# 10         two      sedan          rwd           front  ...         mpfi
#
#     bore  stroke  compression-ratio  horsepower peak-rpm city-L/100km  \
# ...

# %% [markdown]
# **Converting The Datatype**

# %%
df['price']=df['price'].astype('int')

# %% [markdown]
# **Binnig**

# %%
bins=np.linspace(min(df['price']),max(df['price']),4)

# %%
bins
# Out:
# array([ 5118.        , 15097.33333333, 25076.66666667, 35056.        ])

# %%
groupnames=['low','medium','high']
df['price-binned']=pd.cut(df['price'],bins,labels=groupnames)

# %%
df.head(20)
# Out:
#     symboling normalized-losses       make fuel-type aspiration no-of-doors  \
# 3           2               164       audi       gas        std        four
# 4           2               164       audi       gas        std        four
# 6           1               158       audi       gas        std        four
# 8           1               158       audi       gas      turbo        four
# 10          2               192        bmw       gas        std         two
# 11          0               192        bmw       gas        std        four
# 12          0               188        bmw       gas        std         two
# 13          0               188        bmw       gas        std        four
# 18          2               121  chevrolet       gas        std         two
# 19          1                98  chevrolet       gas        std         two
# 20          0                81  chevrolet       gas        std        four
# ...

# %% [markdown]
# **Categorical to Numerical Data**

# %%
pd.get_dummies(df['fuel-type'])
# Out:
#      diesel  gas
# 3         0    1
# 4         0    1
# 6         0    1
# 8         0    1
# 10        0    1
# ..      ...  ...
# 200       0    1
# 201       0    1
# 202       0    1
# 203       1    0
# 204       0    1
#
# [164 rows x 2 columns]

# %% [markdown]
# **GROUP BY**

# %%
df_columns=df[['body-style','make','price']]
df_group= df_columns.groupby(['body-style','make'],as_index=False).mean()
df_group
# Out:
#      body-style           make         price
# 0   convertible  mercedes-benz  35056.000000
# 1   convertible         toyota  17669.000000
# 2       hardtop  mercedes-benz  28176.000000
# 3       hardtop         nissan   8249.000000
# 4       hardtop         toyota   9762.333333
# 5     hatchback      chevrolet   5723.000000
# 6     hatchback          dodge   7819.800000
# 7     hatchback          honda   7054.428571
# 8     hatchback          mazda  10085.000000
# 9     hatchback     mitsubishi   7399.000000
# 10    hatchback         nissan  14409.000000
# 11    hatchback       plymouth   6586.000000
# 12    hatchback        porsche  22018.000000
# 13    hatchback           saab  15013.333333
# 14    hatchback         subaru   6591.333333
# 15    hatchback         toyota   9616.000000
# 16    hatchback     volkswagen   9980.000000
# 17        sedan           audi  18246.250000
# 18        sedan            bmw  18857.500000
# 19        sedan      chevrolet   6575.000000
# ...

# %%
df_columns=df[['body-style','make','price']]
df_group= df_columns.groupby(['body-style','make']).mean()
df_group
# Out:
#                                   price
# body-style  make
# convertible mercedes-benz  35056.000000
#             toyota         17669.000000
# hardtop     mercedes-benz  28176.000000
#             nissan          8249.000000
#             toyota          9762.333333
# hatchback   chevrolet       5723.000000
#             dodge           7819.800000
#             honda           7054.428571
#             mazda          10085.000000
#             mitsubishi      7399.000000
#             nissan         14409.000000
#             plymouth        6586.000000
#             porsche        22018.000000
#             saab           15013.333333
#             subaru          6591.333333
#             toyota          9616.000000
#             volkswagen      9980.000000
# sedan       audi           18246.250000
#             bmw            18857.500000
#             chevrolet       6575.000000
#             dodge           7619.666667
#             honda           9945.000000
# ...

# %%
df_pivot=df_group.pivot(index='body-style',columns='make')
df_pivot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-360e19f8d91c> in <module>
# ----> 1 df_pivot=df_group.pivot(index='body-style',columns='make')
#       2 df_pivot
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    7791         from pandas.core.reshape.pivot import pivot
#    7792
# -> 7793         return pivot(self, index=index, columns=columns, values=values)
#    7794
#    7795     _shared_docs[
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     494         # error: Unsupported operand types for + ("List[Any]" and "ExtensionArray")
#     495         # error: Unsupported left operand type for + ("ExtensionArray")
# --> 496         indexed = data.set_index(
# ...

# %% [markdown]
# **HEAT MAP**

# %%
import matplotlib.pyplot as plt
plt.pcolor(df_pivot,cmap='RdBu')
plt.colorbar()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-7c62abd9a28a> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.pcolor(df_pivot,cmap='RdBu')
#       3 plt.colorbar()
#       4
#       5 plt.show()
#
# NameError: name 'df_pivot' is not defined

# %% [markdown]
# **ANOVA**

# %%
from scipy import stats
df_anovacol=df[['make','price']]
df_groupedanova=df_anovacol.groupby(['make'])
anova_result=stats.f_oneway(df_groupedanova.get_group('honda')['price'],df_groupedanova.get_group('subaru')['price'])
anova_result
# Out:
# F_onewayResult(statistic=0.19744030127462606, pvalue=0.6609478240622193)

# %% [markdown]
# **CORRELATION**

# %%
import seaborn as sns
sns.regplot(x='engine-size',y='price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 37946.86971569258)

# %%
sns.regplot(x='highway-mpg',y='price',data=df)

# %%
df['price'].astype('int')
pearson_coef,pvalue=stats.pearsonr(df['horsepower'],
                        df['price'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'horsepwer'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# **Regression Models**
# y= b0 + b1x  for 1 var
#
# y= b0 + b1x1 +b2x2 +b3x3
#
# X=df[['highway-mpg']]
# Y=df[['price']]
#
# lm.fit(X,Y)
# yhat= lm.predict(X)
#  for b0 -->  lm.intercept_
#  for b1 -->  lm.coef_

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
X=df[['highway-mpg']]
Y=df[['price']]
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
b0=lm.intercept_
b1=lm.coef_
print(b0)
print(b1)
# Out:
# [31586.29724467]
# [[-631.75258436]]

# %%
yhat=lm.predict(X)
print(yhat)
# Out:
# [[ 1.26337197e+04]
#  [ 1.76877404e+04]
#  [ 1.57924826e+04]
#  [ 1.89512456e+04]
#  [ 1.32654723e+04]
#  [ 1.32654723e+04]
#  [ 1.38972249e+04]
#  [ 1.38972249e+04]
#  [-1.89658973e+03]
#  [ 4.42093612e+03]
#  [ 4.42093612e+03]
#  [ 5.68444129e+03]
#  [ 7.57969904e+03]
#  [ 1.26337197e+04]
#  [ 7.57969904e+03]
#  [ 7.57969904e+03]
#  [ 7.57969904e+03]
#  [ 1.26337197e+04]
#  [ 1.26337197e+04]
#  [ 1.64242352e+04]
#  [-2.52834231e+03]
#  [ 7.57969904e+03]
#  [ 5.05268870e+03]
#  [ 1.01067094e+04]
#  [ 1.01067094e+04]
#  [ 1.01067094e+04]
#  [ 1.01067094e+04]
#  [ 1.07384620e+04]
#  [ 1.07384620e+04]
#  [ 1.07384620e+04]
#  [ 1.07384620e+04]
#  [ 1.38972249e+04]
#  [ 1.20019671e+04]
#  [ 1.95829981e+04]
#  [ 1.20019671e+04]
#  [ 7.57969904e+03]
#  [ 7.57969904e+03]
#  [ 7.57969904e+03]
#  [ 7.57969904e+03]
#  [ 1.70559878e+04]
#  [ 1.70559878e+04]
#  [ 1.70559878e+04]
#  [ 1.70559878e+04]
#  [ 1.13702145e+04]
#  [ 1.13702145e+04]
#  [ 1.13702145e+04]
#  [ 1.13702145e+04]
# ...

# %% [markdown]
# **NOW GOT MY MODEL WITH THE HELP OF b0 and b1**

# %%
y=31586.29724467+(-631.75258436*X)
print(y)
# Out:
#       highway-mpg
# 3    12633.719714
# 4    17687.740389
# 6    15792.482636
# 8    18951.245557
# 10   13265.472298
# ..            ...
# 200  13897.224883
# 201  15792.482636
# 202  17055.987804
# 203  14528.977467
# 204  15792.482636
#
# [164 rows x 1 columns]

# %%
sns.regplot('highway-mpg','price',data=df)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.residplot('highway-mpg','price',data=df)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ax1=sns.distplot(df['price'],hist=False,color='r',label='actualvalue')
sns.distplot(yhat,hist=False,color='b',label='predictedvalue',ax=ax1)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Numerical or In sample evaluatioin of model**
# for MSE
#
# from sklearn.metrics import mean_squared_error
# mean_squarred error(df['price'],Y_predict_simple_fit)

# %%
from sklearn.metrics import mean_squared_error
mean_squarred error(df['price'],Y_predict_simple_fit)
# Out:
#   File "<ipython-input-63-d525a60c387d>", line 2
#     mean_squarred error(df['price'],Y_predict_simple_fit)
#                   ^
# SyntaxError: invalid syntax
